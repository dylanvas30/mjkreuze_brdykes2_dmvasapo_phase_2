# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import math

from scipy import stats

# %%
shark_attacks = pd.read_csv("GSAF5.xls.csv")
print(len(shark_attacks))
print(shark_attacks.dtypes)

# Note that columns 10, 17, 18, 19, 20, 21, 24 have "mixed types".
# Also note that from column 22 and onwards, there are extra columns that have no data up to column 255.
# 10 = Unnamed: 9 (M or F or empty)
# 17 = pdf
# 18 = href formula
# 19 = href
# 20 = Case Number.1
# 21 = Case Number.2
# 24 = Unnamed:23 (seems to be a total of 2-3 random notes from a data cataloguer)
# Out:
# 6462
# index             int64
# Case Number      object
# Date             object
# Year            float64
# Type             object
#                  ...
# Unnamed: 251    float64
# Unnamed: 252    float64
# Unnamed: 253    float64
# Unnamed: 254    float64
# Unnamed: 255    float64
# Length: 257, dtype: object
# C:\Users\skyli\AppData\Local\Temp\ipykernel_12400\2291830759.py:1: DtypeWarning: Columns (10,17,18,19,20,21,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   shark_attacks = pd.read_csv("GSAF5.xls.csv")

# %%
# Step 1: Remove bogus columns.

shark_attacks = shark_attacks[["index", "Case Number", "Date", "Year", "Type", "Country", "Area", "Location", "Activity", "Name", "Unnamed: 9", "Age", "Injury", "Fatal (Y/N)", "Time", "Species ", "Investigator or Source", "pdf", "href formula", "href", "Case Number.1", "Case Number.2", "original order"]]

shark_attacks
# Out:
#       index   Case Number                  Date    Year        Type  \
# 0         0    2020.02.05              5-Feb-20  2020.0  Unprovoked
# 1         1  2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked
# 2         2    2020.01.17             17-Jan-20  2020.0  Unprovoked
# 3         3    2020.01.16             16-Jan-20  2020.0  Unprovoked
# 4         4    2020.01.13             13-Jan-20  2020.0  Unprovoked
# ...     ...           ...                   ...     ...         ...
# 6457   6457       ND.0005           Before 1903     0.0  Unprovoked
# 6458   6458       ND.0004           Before 1903     0.0  Unprovoked
# 6459   6459       ND.0003             1900-1905     0.0  Unprovoked
# 6460   6460       ND.0002             1883-1889     0.0  Unprovoked
# 6461   6461       ND.0001             1845-1853     0.0  Unprovoked
#
#                  Country               Area  \
# 0                    USA               Maui
# 1                BAHAMAS             Exumas
# 2              AUSTRALIA    New South Wales
# 3            NEW ZEALAND          Southland
# 4                    USA     North Carolina
# ...                  ...                ...
# 6457           AUSTRALIA  Western Australia
# 6458           AUSTRALIA  Western Australia
# 6459                 USA     North Carolina
# 6460              PANAMA                NaN
# 6461  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location                  Activity  \
# 0                                     NaN  Stand-Up Paddle boarding
# 1                                     NaN                  Floating
# 2                           Windang Beach                   Surfing
# 3                             Oreti Beach                   Surfing
# 4                   Rodanthe, Dare County                   Surfing
# ...                                   ...                       ...
# 6457                          Roebuck Bay                    Diving
# 6458                                  NaN              Pearl diving
# 6459                       Ocracoke Inlet                  Swimming
# 6460                 Panama Bay 8ºN, 79ºW                       NaN
# 6461  Below the English fort, Trincomalee                  Swimming
#
#                        Name  ... Fatal (Y/N)   Time  \
# 0                       NaN  ...           N  09h40
# 1           Ana Bruna Avila  ...           N    NaN
# 2            Will Schroeter  ...           N  08h00
# 3               Jordan King  ...           N  20h30
# 4              Samuel Horne  ...           N  14h33
# ...                     ...  ...         ...    ...
# 6457                   male  ...           Y    NaN
# 6458                  Ahmun  ...           Y    NaN
# 6459  Coast Guard personnel  ...           Y    NaN
# 6460        Jules Patterson  ...           Y    NaN
# 6461                   male  ...           Y    NaN
#
#                          Species   \
# 0                     Tiger shark
# 1                             NaN
# 2                 "A small shark"
# 3     Broadnose seven gill shark?
# 4                             NaN
# ...                           ...
# 6457                          NaN
# 6458                          NaN
# 6459                          NaN
# 6460                          NaN
# 6461                          NaN
#
#                                  Investigator or Source  \
# 0                       K. McMurray, TrackingSharks.com
# 1                       K. McMurray, TrackingSharks.com
# 2     B. Myatt & M. Michaelson, GSAF; K. McMurray, T...
# 3                       K. McMurray, TrackingSharks.com
# 4                                     C. Creswell, GSAF
# ...                                                 ...
# 6457                    H. Taunton; N. Bartlett, p. 234
# 6458               H. Taunton; N. Bartlett, pp. 233-234
# 6459               F. Schwartz, p.23; C. Creswell, GSAF
# 6460                                The Sun, 10/20/1938
# 6461                                         S.W. Baker
#
#                            pdf  \
# 0                          NaN
# 1                          NaN
# 2     2020.01.17-Schroeter.pdf
# 3          2020.01.16-King.pdf
# 4         2020.01.13-Horne.pdf
# ...                        ...
# 6457                       NaN
# 6458                       NaN
# 6459                       NaN
# 6460                       NaN
# 6461                       NaN
#
#                                            href formula  \
# 0                                                   NaN
# 1                                                   NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6457                                                NaN
# 6458                                                NaN
# 6459                                                NaN
# 6460                                                NaN
# 6461                                                NaN
#
#                                                    href Case Number.1  \
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2020.01.17
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2020.01.16
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2020.01.13
# ...                                                 ...           ...
# 6457                                                NaN           NaN
# 6458                                                NaN           NaN
# 6459                                                NaN           NaN
# 6460                                                NaN           NaN
# 6461                                                NaN           NaN
#
#      Case Number.2 original order
# 0              NaN            NaN
# 1              NaN            NaN
# 2       2020.01.17         6502.0
# 3       2020.01.16         6501.0
# 4       2020.01.13         6500.0
# ...            ...            ...
# 6457           NaN            NaN
# 6458           NaN            NaN
# 6459           NaN            NaN
# 6460           NaN            NaN
# 6461           NaN            NaN
#
# [6462 rows x 23 columns]

# %%
# Step 2: Remove irrelevant columns for  ("Investigator or Source", "Case Number", "Name", "Case Number.1", "Case Number.2", "pdf", "href formula", "href", "original order").

shark_attacks = shark_attacks[["index", "Date", "Year", "Type", "Country", "Area", "Location", "Activity", "Unnamed: 9", "Age", "Injury", "Fatal (Y/N)", "Time", "Species "]]

shark_attacks
# Out:
#       index                  Date    Year        Type             Country  \
# 0         0              5-Feb-20  2020.0  Unprovoked                 USA
# 1         1  Reported 30-Jan-2020  2020.0    Provoked             BAHAMAS
# 2         2             17-Jan-20  2020.0  Unprovoked           AUSTRALIA
# 3         3             16-Jan-20  2020.0  Unprovoked         NEW ZEALAND
# 4         4             13-Jan-20  2020.0  Unprovoked                 USA
# ...     ...                   ...     ...         ...                 ...
# 6457   6457           Before 1903     0.0  Unprovoked           AUSTRALIA
# 6458   6458           Before 1903     0.0  Unprovoked           AUSTRALIA
# 6459   6459             1900-1905     0.0  Unprovoked                 USA
# 6460   6460             1883-1889     0.0  Unprovoked              PANAMA
# 6461   6461             1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location  \
# 0                  Maui                                  NaN
# 1                Exumas                                  NaN
# 2       New South Wales                        Windang Beach
# 3             Southland                          Oreti Beach
# 4        North Carolina                Rodanthe, Dare County
# ...                 ...                                  ...
# 6457  Western Australia                          Roebuck Bay
# 6458  Western Australia                                  NaN
# 6459     North Carolina                       Ocracoke Inlet
# 6460                NaN                 Panama Bay 8ºN, 79ºW
# 6461   Eastern Province  Below the English fort, Trincomalee
#
#                       Activity Unnamed: 9  Age  \
# 0     Stand-Up Paddle boarding        NaN  20s
# 1                     Floating          F   24
# 2                      Surfing          M   59
# 3                      Surfing          F   13
# 4                      Surfing          M   26
# ...                        ...        ...  ...
# 6457                    Diving        NaN  NaN
# 6458              Pearl diving        NaN  NaN
# 6459                  Swimming        NaN  NaN
# 6460                       NaN        NaN  NaN
# 6461                  Swimming        NaN   15
#
#                                                  Injury Fatal (Y/N)   Time  \
# 0                     No injury, but paddleboard bitten           N  09h40
# 1             PROVOKED INCIDENT Scratches to left wrist           N    NaN
# 2                     Laceration ot left ankle and foot           N  08h00
# 3                             Minor injury to lower leg           N  20h30
# 4                                   Lacerations to foot           N  14h33
# ...                                                 ...         ...    ...
# 6457                                              FATAL           Y    NaN
# 6458                                              FATAL           Y    NaN
# 6459                                              FATAL           Y    NaN
# 6460                                              FATAL           Y    NaN
# 6461  FATAL. "Shark bit him in half, carrying away t...           Y    NaN
#
#                          Species
# 0                     Tiger shark
# 1                             NaN
# 2                 "A small shark"
# 3     Broadnose seven gill shark?
# 4                             NaN
# ...                           ...
# 6457                          NaN
# 6458                          NaN
# 6459                          NaN
# 6460                          NaN
# 6461                          NaN
#
# [6462 rows x 14 columns]

# %%
# Step 3: Clean "Age" column to include those with known ages.

def clean_age(age):

    sage = str(age)  # Transform age to a string for easier verification.

    # If the age contains more than just digits...

    if not sage.isdigit():

        # If the age ends with "s", replace last digit with a "5" and remove the "s" (e.g. assume "30s" is "35", being the average between 30 and 40).

        if sage[-1] == "s":

            lage = list(sage)  # Transform the string into a list in order to do inplace editing.

            lage[-2] = "5"
            lage.pop()
            
            return "".join(lage)  # Return the list as a string.

        return sage  # No other operation performed for cleaning.

    return sage  # Was already clean.

shark_attacks["Age"] = shark_attacks["Age"].apply(clean_age)  # Modify values to be acceptable, where possible.
shark_attacks = shark_attacks[shark_attacks["Age"].str.match("^[0-9]+$")]  # Reduce matches to only those ages that are exact numbers.
shark_attacks
# Out:
# C:\Users\skyli\AppData\Local\Temp\ipykernel_12400\2609986971.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_attacks["Age"] = shark_attacks["Age"].apply(clean_age)  # Modify values to be acceptable, where possible.
#       index                  Date    Year        Type             Country  \
# 0         0              5-Feb-20  2020.0  Unprovoked                 USA
# 1         1  Reported 30-Jan-2020  2020.0    Provoked             BAHAMAS
# 2         2             17-Jan-20  2020.0  Unprovoked           AUSTRALIA
# 3         3             16-Jan-20  2020.0  Unprovoked         NEW ZEALAND
# 4         4             13-Jan-20  2020.0  Unprovoked                 USA
# ...     ...                   ...     ...         ...                 ...
# 6402   6402                 1960s     0.0  Unprovoked                IRAQ
# 6403   6403                 1960s     0.0  Unprovoked                IRAQ
# 6414   6414           Before 1957     0.0    Provoked                CUBA
# 6436   6436           Early 1930s     0.0  Unprovoked              BELIZE
# 6461   6461             1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                   Area                                Location  \
# 0                 Maui                                     NaN
# 1               Exumas                                     NaN
# 2      New South Wales                           Windang Beach
# 3            Southland                             Oreti Beach
# 4       North Carolina                   Rodanthe, Dare County
# ...                ...                                     ...
# 6402            Basrah                     Shatt-al-Arab River
# 6403            Basrah  Shatt-al-Arab River near Abu al Khasib
# 6414   Havana Province                                 Cojimar
# 6436               NaN                                     NaN
# 6461  Eastern Province     Below the English fort, Trincomalee
#
#                                                Activity Unnamed: 9 Age  \
# 0                              Stand-Up Paddle boarding        NaN  25
# 1                                              Floating          F  24
# 2                                               Surfing          M  59
# 3                                               Surfing          F  13
# 4                                               Surfing          M  26
# ...                                                 ...        ...  ..
# 6402  Swimming naked near a date palm where many dat...        NaN   6
# 6403  Swimming in section of river used for washing ...        NaN  16
# 6414                   Shark fishing, knocked overboard        NaN  50
# 6436                                           Standing        NaN  16
# 6461                                           Swimming        NaN  15
#
#                                                  Injury Fatal (Y/N)  \
# 0                     No injury, but paddleboard bitten           N
# 1             PROVOKED INCIDENT Scratches to left wrist           N
# 2                     Laceration ot left ankle and foot           N
# 3                             Minor injury to lower leg           N
# 4                                   Lacerations to foot           N
# ...                                                 ...         ...
# 6402                                        Arm severed           N
# 6403         Right leg lacerated & surgically amputated           N
# 6414                FATAL, hip bitten PROVOKED INCIDENT           Y
# 6436                                              FATAL           Y
# 6461  FATAL. "Shark bit him in half, carrying away t...           Y
#
#            Time                     Species
# 0         09h40                  Tiger shark
# 1           NaN                          NaN
# 2         08h00              "A small shark"
# 3         20h30  Broadnose seven gill shark?
# 4         14h33                          NaN
# ...         ...                          ...
# 6402  Afternoon                   Bull shark
# 6403  Afternoon                   Bull shark
# 6414        NaN                          NaN
# 6436        NaN              12' tiger shark
# 6461        NaN                          NaN
#
# [3511 rows x 14 columns]

# %%
# Step 4: Clean "Date" column to have a uniform date. Exclude rows where no exact date is known.

def clean_date(date):

    # Transform NaN into strings, to be ejected later.

    if not isinstance(date, str):
        return ""
    
    re_match = re.match("^(Reported )?([0-9]+)(/|-|\.)([0-9a-zA-Z]+)(/|-|\.)+([0-9]+)$", date)

    # If there was a match for the generally-expected input...
    
    if re_match != None:

        day = re_match.group(2)
        month = re_match.group(4)
        year = re_match.group(6)

        # If the day is 4 characters long, format input was year.month.day, so swap the year and day.

        if  len(day) == 4:
            daytemp = day
            day = year
            year = daytemp

        # If the year was only 2 characters long, assume the year to be 2020.
            
        if len(year) == 2:
            year = '20' + year

        # If the month was not numeric, make it so.

        if not month.isdigit():
            if month == 'Jan':
                month = '1'
            elif month == 'Feb':
                month = '2'
            elif month == 'Mar':
                month = '3'
            elif month == 'Apr':
                month = '4'
            elif month == 'May':
                month = '5'
            elif month == 'Jun':
                month = '6'
            elif month == 'Jul':
                month = '7'
            elif month == 'Aug':
                month = '8'
            elif month == 'Sep':
                month = '9'
            elif month == 'Oct':
                month = '10'
            elif month == 'Nov':
                month = '11'
            elif month == 'Dec':
                month = '12'

        # Return a normalized date.

        return month + '/' + day + '/' + year

    # Did not match expected format, set to empty (to mark it for deletion after).

    return ""

shark_attacks["Date"] = shark_attacks["Date"].apply(clean_date)
shark_attacks = shark_attacks[~shark_attacks["Date"].str.match("^$")]  # Remove columns that became empty as a result of cleaning.

shark_attacks
# Out:
# C:\Users\skyli\AppData\Local\Temp\ipykernel_12400\296291635.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_attacks["Date"] = shark_attacks["Date"].apply(clean_date)
#       index       Date    Year        Type       Country              Area  \
# 0         0   2/5/2020  2020.0  Unprovoked           USA              Maui
# 1         1  1/30/2020  2020.0    Provoked       BAHAMAS            Exumas
# 2         2  1/17/2020  2020.0  Unprovoked     AUSTRALIA   New South Wales
# 3         3  1/16/2020  2020.0  Unprovoked   NEW ZEALAND         Southland
# 4         4  1/13/2020  2020.0  Unprovoked           USA    North Carolina
# ...     ...        ...     ...         ...           ...               ...
# 6237   6237  1/17/1837  1837.0  Unprovoked     AUSTRALIA   New South Wales
# 6249   6249  7/26/1830  1830.0  Unprovoked           USA     Massachusetts
# 6256   6256  9/28/1828  1828.0  Unprovoked  SIERRA LEONE      Western Area
# 6274   6274  5/11/1817  1817.0  Unprovoked     SRI LANKA  Western Province
# 6320   6320  3/26/1703  1703.0  Unprovoked      BARBADOS   Southwest coast
#
#                                                Location  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                         Windang Beach
# 3                                           Oreti Beach
# 4                                 Rodanthe, Dare County
# ...                                                 ...
# 6237                                      Macleay River
# 6249                           Swampscott, Essex County
# 6256  River Sierra Leone, 35 miles upriver from Free...
# 6274                                            Colombo
# 6320                                       Carlisle Bay
#
#                                                Activity Unnamed: 9 Age  \
# 0                              Stand-Up Paddle boarding        NaN  25
# 1                                              Floating          F  24
# 2                                               Surfing          M  59
# 3                                               Surfing          F  13
# 4                                               Surfing          M  26
# ...                                                 ...        ...  ..
# 6237                                   Washing his feet        NaN  12
# 6249  Fishing from dory, shark upset boat & he fell ...        NaN  52
# 6256  British ship, Britannia, was loading lumber. H...        NaN  17
# 6274                                           Swimming        NaN  22
# 6320                                           Swimming        NaN  19
#
#                                                  Injury Fatal (Y/N)     Time  \
# 0                     No injury, but paddleboard bitten           N    09h40
# 1             PROVOKED INCIDENT Scratches to left wrist           N      NaN
# 2                     Laceration ot left ankle and foot           N    08h00
# 3                             Minor injury to lower leg           N    20h30
# 4                                   Lacerations to foot           N    14h33
# ...                                                 ...         ...      ...
# 6237            FATAL Injured by shark, died of tetanus           Y  Evening
# 6249                                              FATAL           Y      NaN
# 6256  Left arm severed 2.5" from elbow, groin, abdom...           N      NaN
# 6274                                              FATAL           Y  Evening
# 6320  Hand and foot severely bitten, surgically ampu...           N    Night
#
#                          Species
# 0                     Tiger shark
# 1                             NaN
# 2                 "A small shark"
# 3     Broadnose seven gill shark?
# 4                             NaN
# ...                           ...
# 6237                          NaN
# 6249                          NaN
# 6256                          NaN
# 6274                          NaN
# 6320                          NaN
#
# [3343 rows x 14 columns]

# %%
# Step 5: Split the "Date" column up into 3 new columns: "Day", "Month", and "Year".

shark_attacks[['Month', 'Day', 'Year']] = shark_attacks['Date'].str.split('/', expand=True)
shark_attacks = shark_attacks.drop('Date', axis=1)  # "Date" column no longer needed.

shark_attacks
# Out:
# C:\Users\skyli\AppData\Local\Temp\ipykernel_12400\1218471878.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_attacks[['Month', 'Day', 'Year']] = shark_attacks['Date'].str.split('/', expand=True)
# C:\Users\skyli\AppData\Local\Temp\ipykernel_12400\1218471878.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_attacks[['Month', 'Day', 'Year']] = shark_attacks['Date'].str.split('/', expand=True)
#       index  Year        Type       Country              Area  \
# 0         0  2020  Unprovoked           USA              Maui
# 1         1  2020    Provoked       BAHAMAS            Exumas
# 2         2  2020  Unprovoked     AUSTRALIA   New South Wales
# 3         3  2020  Unprovoked   NEW ZEALAND         Southland
# 4         4  2020  Unprovoked           USA    North Carolina
# ...     ...   ...         ...           ...               ...
# 6237   6237  1837  Unprovoked     AUSTRALIA   New South Wales
# 6249   6249  1830  Unprovoked           USA     Massachusetts
# 6256   6256  1828  Unprovoked  SIERRA LEONE      Western Area
# 6274   6274  1817  Unprovoked     SRI LANKA  Western Province
# 6320   6320  1703  Unprovoked      BARBADOS   Southwest coast
#
#                                                Location  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                         Windang Beach
# 3                                           Oreti Beach
# 4                                 Rodanthe, Dare County
# ...                                                 ...
# 6237                                      Macleay River
# 6249                           Swampscott, Essex County
# 6256  River Sierra Leone, 35 miles upriver from Free...
# 6274                                            Colombo
# 6320                                       Carlisle Bay
#
#                                                Activity Unnamed: 9 Age  \
# 0                              Stand-Up Paddle boarding        NaN  25
# 1                                              Floating          F  24
# 2                                               Surfing          M  59
# 3                                               Surfing          F  13
# 4                                               Surfing          M  26
# ...                                                 ...        ...  ..
# 6237                                   Washing his feet        NaN  12
# 6249  Fishing from dory, shark upset boat & he fell ...        NaN  52
# 6256  British ship, Britannia, was loading lumber. H...        NaN  17
# 6274                                           Swimming        NaN  22
# 6320                                           Swimming        NaN  19
#
#                                                  Injury Fatal (Y/N)     Time  \
# 0                     No injury, but paddleboard bitten           N    09h40
# 1             PROVOKED INCIDENT Scratches to left wrist           N      NaN
# 2                     Laceration ot left ankle and foot           N    08h00
# 3                             Minor injury to lower leg           N    20h30
# 4                                   Lacerations to foot           N    14h33
# ...                                                 ...         ...      ...
# 6237            FATAL Injured by shark, died of tetanus           Y  Evening
# 6249                                              FATAL           Y      NaN
# 6256  Left arm severed 2.5" from elbow, groin, abdom...           N      NaN
# 6274                                              FATAL           Y  Evening
# 6320  Hand and foot severely bitten, surgically ampu...           N    Night
#
#                          Species  Month Day
# 0                     Tiger shark     2   5
# 1                             NaN     1  30
# 2                 "A small shark"     1  17
# 3     Broadnose seven gill shark?     1  16
# 4                             NaN     1  13
# ...                           ...   ...  ..
# 6237                          NaN     1  17
# 6249                          NaN     7  26
# 6256                          NaN     9  28
# 6274                          NaN     5  11
# 6320                          NaN     3  26
#
# [3343 rows x 15 columns]

# %%
# Step 6: Remove rows where the type of attack is "Under Investigation" (don't know if it's a shark attack) or "Invalid" (it was not a shark attack).

def clean_type(type):
    if not isinstance(type, str):
        return ""
    return type

shark_attacks["Type"] = shark_attacks["Type"].apply(clean_type)
shark_attacks = shark_attacks[~shark_attacks["Type"].str.match("^Invalid$")]

shark_attacks
# Out:
#       index  Year        Type       Country              Area  \
# 0         0  2020  Unprovoked           USA              Maui
# 1         1  2020    Provoked       BAHAMAS            Exumas
# 2         2  2020  Unprovoked     AUSTRALIA   New South Wales
# 3         3  2020  Unprovoked   NEW ZEALAND         Southland
# 4         4  2020  Unprovoked           USA    North Carolina
# ...     ...   ...         ...           ...               ...
# 6237   6237  1837  Unprovoked     AUSTRALIA   New South Wales
# 6249   6249  1830  Unprovoked           USA     Massachusetts
# 6256   6256  1828  Unprovoked  SIERRA LEONE      Western Area
# 6274   6274  1817  Unprovoked     SRI LANKA  Western Province
# 6320   6320  1703  Unprovoked      BARBADOS   Southwest coast
#
#                                                Location  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                         Windang Beach
# 3                                           Oreti Beach
# 4                                 Rodanthe, Dare County
# ...                                                 ...
# 6237                                      Macleay River
# 6249                           Swampscott, Essex County
# 6256  River Sierra Leone, 35 miles upriver from Free...
# 6274                                            Colombo
# 6320                                       Carlisle Bay
#
#                                                Activity Unnamed: 9 Age  \
# 0                              Stand-Up Paddle boarding        NaN  25
# 1                                              Floating          F  24
# 2                                               Surfing          M  59
# 3                                               Surfing          F  13
# 4                                               Surfing          M  26
# ...                                                 ...        ...  ..
# 6237                                   Washing his feet        NaN  12
# 6249  Fishing from dory, shark upset boat & he fell ...        NaN  52
# 6256  British ship, Britannia, was loading lumber. H...        NaN  17
# 6274                                           Swimming        NaN  22
# 6320                                           Swimming        NaN  19
#
#                                                  Injury Fatal (Y/N)     Time  \
# 0                     No injury, but paddleboard bitten           N    09h40
# 1             PROVOKED INCIDENT Scratches to left wrist           N      NaN
# 2                     Laceration ot left ankle and foot           N    08h00
# 3                             Minor injury to lower leg           N    20h30
# 4                                   Lacerations to foot           N    14h33
# ...                                                 ...         ...      ...
# 6237            FATAL Injured by shark, died of tetanus           Y  Evening
# 6249                                              FATAL           Y      NaN
# 6256  Left arm severed 2.5" from elbow, groin, abdom...           N      NaN
# 6274                                              FATAL           Y  Evening
# 6320  Hand and foot severely bitten, surgically ampu...           N    Night
#
#                          Species  Month Day
# 0                     Tiger shark     2   5
# 1                             NaN     1  30
# 2                 "A small shark"     1  17
# 3     Broadnose seven gill shark?     1  16
# 4                             NaN     1  13
# ...                           ...   ...  ..
# 6237                          NaN     1  17
# 6249                          NaN     7  26
# 6256                          NaN     9  28
# 6274                          NaN     5  11
# 6320                          NaN     3  26
#
# [3128 rows x 15 columns]

# %%
# Step 7: Remove rows where the "Country" and "Location" is empty or inexact.

def clean_empty(data):

    if not isinstance(data, str):
        return ""

    return data

shark_attacks["Country"] = shark_attacks["Country"].apply(clean_empty)
shark_attacks["Area"] = shark_attacks["Area"].apply(clean_empty)
shark_attacks["Location"] = shark_attacks["Location"].apply(clean_empty)
shark_attacks = shark_attacks[shark_attacks["Country"].str.match("^.+$")]
shark_attacks = shark_attacks[shark_attacks["Area"].str.match("^.+$")]
shark_attacks = shark_attacks[shark_attacks["Location"].str.match("^.+$")]
shark_attacks
# Out:
# C:\Users\skyli\AppData\Local\Temp\ipykernel_12400\224201197.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_attacks["Country"] = shark_attacks["Country"].apply(clean_empty)
# C:\Users\skyli\AppData\Local\Temp\ipykernel_12400\224201197.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_attacks["Area"] = shark_attacks["Area"].apply(clean_empty)
# C:\Users\skyli\AppData\Local\Temp\ipykernel_12400\224201197.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_attacks["Location"] = shark_attacks["Location"].apply(clean_empty)
#       index  Year        Type       Country                Area  \
# 2         2  2020  Unprovoked     AUSTRALIA     New South Wales
# 3         3  2020  Unprovoked   NEW ZEALAND           Southland
# 4         4  2020  Unprovoked           USA      North Carolina
# 5         5  2020  Unprovoked      THAILAND  Phang Nga Province
# 6         6  2020  Unprovoked     AUSTRALIA          Queensland
# ...     ...   ...         ...           ...                 ...
# 6237   6237  1837  Unprovoked     AUSTRALIA     New South Wales
# 6249   6249  1830  Unprovoked           USA       Massachusetts
# 6256   6256  1828  Unprovoked  SIERRA LEONE        Western Area
# 6274   6274  1817  Unprovoked     SRI LANKA    Western Province
# 6320   6320  1703  Unprovoked      BARBADOS     Southwest coast
#
#                                                Location  \
# 2                                         Windang Beach
# 3                                           Oreti Beach
# 4                                 Rodanthe, Dare County
# 5                                      Nang Thong Beach
# 6                                     North West Island
# ...                                                 ...
# 6237                                      Macleay River
# 6249                           Swampscott, Essex County
# 6256  River Sierra Leone, 35 miles upriver from Free...
# 6274                                            Colombo
# 6320                                       Carlisle Bay
#
#                                                Activity Unnamed: 9 Age  \
# 2                                               Surfing          M  59
# 3                                               Surfing          F  13
# 4                                               Surfing          M  26
# 5                                              Swimming          M  75
# 6                                              Swimming          F   7
# ...                                                 ...        ...  ..
# 6237                                   Washing his feet        NaN  12
# 6249  Fishing from dory, shark upset boat & he fell ...        NaN  52
# 6256  British ship, Britannia, was loading lumber. H...        NaN  17
# 6274                                           Swimming        NaN  22
# 6320                                           Swimming        NaN  19
#
#                                                  Injury Fatal (Y/N)     Time  \
# 2                     Laceration ot left ankle and foot           N    08h00
# 3                             Minor injury to lower leg           N    20h30
# 4                                   Lacerations to foot           N    14h33
# 5                                           Calf bitten           N    07h15
# 6                                    Lacerations to leg           N    17h30
# ...                                                 ...         ...      ...
# 6237            FATAL Injured by shark, died of tetanus           Y  Evening
# 6249                                              FATAL           Y      NaN
# 6256  Left arm severed 2.5" from elbow, groin, abdom...           N      NaN
# 6274                                              FATAL           Y  Evening
# 6320  Hand and foot severely bitten, surgically ampu...           N    Night
#
#                          Species  Month Day
# 2                 "A small shark"     1  17
# 3     Broadnose seven gill shark?     1  16
# 4                             NaN     1  13
# 5                             NaN     1  12
# 6                     Lemon shark     1   7
# ...                           ...   ...  ..
# 6237                          NaN     1  17
# 6249                          NaN     7  26
# 6256                          NaN     9  28
# 6274                          NaN     5  11
# 6320                          NaN     3  26
#
# [2965 rows x 15 columns]

# %%
# Step 8: Replace values of "F" with "Y" in column "Fatal (Y/N)".

def clean_fatal(fatal):

    # If already known, skip it.

    if fatal == "Y" or fatal == "N":
        return fatal
    
    # If "F", return "Y".

    if fatal == "F":
        return "Y"
    
    # Some other invalid value (e.g. "M" or "2017" or "NaN")
    
    return "UNKNOWN"

shark_attacks["Fatal (Y/N)"] = shark_attacks["Fatal (Y/N)"].apply(clean_fatal)

shark_attacks
# Out:
#       index  Year        Type       Country                Area  \
# 2         2  2020  Unprovoked     AUSTRALIA     New South Wales
# 3         3  2020  Unprovoked   NEW ZEALAND           Southland
# 4         4  2020  Unprovoked           USA      North Carolina
# 5         5  2020  Unprovoked      THAILAND  Phang Nga Province
# 6         6  2020  Unprovoked     AUSTRALIA          Queensland
# ...     ...   ...         ...           ...                 ...
# 6237   6237  1837  Unprovoked     AUSTRALIA     New South Wales
# 6249   6249  1830  Unprovoked           USA       Massachusetts
# 6256   6256  1828  Unprovoked  SIERRA LEONE        Western Area
# 6274   6274  1817  Unprovoked     SRI LANKA    Western Province
# 6320   6320  1703  Unprovoked      BARBADOS     Southwest coast
#
#                                                Location  \
# 2                                         Windang Beach
# 3                                           Oreti Beach
# 4                                 Rodanthe, Dare County
# 5                                      Nang Thong Beach
# 6                                     North West Island
# ...                                                 ...
# 6237                                      Macleay River
# 6249                           Swampscott, Essex County
# 6256  River Sierra Leone, 35 miles upriver from Free...
# 6274                                            Colombo
# 6320                                       Carlisle Bay
#
#                                                Activity Unnamed: 9 Age  \
# 2                                               Surfing          M  59
# 3                                               Surfing          F  13
# 4                                               Surfing          M  26
# 5                                              Swimming          M  75
# 6                                              Swimming          F   7
# ...                                                 ...        ...  ..
# 6237                                   Washing his feet        NaN  12
# 6249  Fishing from dory, shark upset boat & he fell ...        NaN  52
# 6256  British ship, Britannia, was loading lumber. H...        NaN  17
# 6274                                           Swimming        NaN  22
# 6320                                           Swimming        NaN  19
#
#                                                  Injury Fatal (Y/N)     Time  \
# 2                     Laceration ot left ankle and foot           N    08h00
# 3                             Minor injury to lower leg           N    20h30
# 4                                   Lacerations to foot           N    14h33
# 5                                           Calf bitten           N    07h15
# 6                                    Lacerations to leg           N    17h30
# ...                                                 ...         ...      ...
# 6237            FATAL Injured by shark, died of tetanus           Y  Evening
# 6249                                              FATAL           Y      NaN
# 6256  Left arm severed 2.5" from elbow, groin, abdom...           N      NaN
# 6274                                              FATAL           Y  Evening
# 6320  Hand and foot severely bitten, surgically ampu...           N    Night
#
#                          Species  Month Day
# 2                 "A small shark"     1  17
# 3     Broadnose seven gill shark?     1  16
# 4                             NaN     1  13
# 5                             NaN     1  12
# 6                     Lemon shark     1   7
# ...                           ...   ...  ..
# 6237                          NaN     1  17
# 6249                          NaN     7  26
# 6256                          NaN     9  28
# 6274                          NaN     5  11
# 6320                          NaN     3  26
#
# [2965 rows x 15 columns]

# %%
# Step 9: Remove rows where there is no value for the "Fatal (Y/N)" column.
shark_attacks = shark_attacks[shark_attacks["Fatal (Y/N)"].str.match("^Y|N$")]

shark_attacks
# Out:
#       index  Year        Type       Country                Area  \
# 2         2  2020  Unprovoked     AUSTRALIA     New South Wales
# 3         3  2020  Unprovoked   NEW ZEALAND           Southland
# 4         4  2020  Unprovoked           USA      North Carolina
# 5         5  2020  Unprovoked      THAILAND  Phang Nga Province
# 6         6  2020  Unprovoked     AUSTRALIA          Queensland
# ...     ...   ...         ...           ...                 ...
# 6237   6237  1837  Unprovoked     AUSTRALIA     New South Wales
# 6249   6249  1830  Unprovoked           USA       Massachusetts
# 6256   6256  1828  Unprovoked  SIERRA LEONE        Western Area
# 6274   6274  1817  Unprovoked     SRI LANKA    Western Province
# 6320   6320  1703  Unprovoked      BARBADOS     Southwest coast
#
#                                                Location  \
# 2                                         Windang Beach
# 3                                           Oreti Beach
# 4                                 Rodanthe, Dare County
# 5                                      Nang Thong Beach
# 6                                     North West Island
# ...                                                 ...
# 6237                                      Macleay River
# 6249                           Swampscott, Essex County
# 6256  River Sierra Leone, 35 miles upriver from Free...
# 6274                                            Colombo
# 6320                                       Carlisle Bay
#
#                                                Activity Unnamed: 9 Age  \
# 2                                               Surfing          M  59
# 3                                               Surfing          F  13
# 4                                               Surfing          M  26
# 5                                              Swimming          M  75
# 6                                              Swimming          F   7
# ...                                                 ...        ...  ..
# 6237                                   Washing his feet        NaN  12
# 6249  Fishing from dory, shark upset boat & he fell ...        NaN  52
# 6256  British ship, Britannia, was loading lumber. H...        NaN  17
# 6274                                           Swimming        NaN  22
# 6320                                           Swimming        NaN  19
#
#                                                  Injury Fatal (Y/N)     Time  \
# 2                     Laceration ot left ankle and foot           N    08h00
# 3                             Minor injury to lower leg           N    20h30
# 4                                   Lacerations to foot           N    14h33
# 5                                           Calf bitten           N    07h15
# 6                                    Lacerations to leg           N    17h30
# ...                                                 ...         ...      ...
# 6237            FATAL Injured by shark, died of tetanus           Y  Evening
# 6249                                              FATAL           Y      NaN
# 6256  Left arm severed 2.5" from elbow, groin, abdom...           N      NaN
# 6274                                              FATAL           Y  Evening
# 6320  Hand and foot severely bitten, surgically ampu...           N    Night
#
#                          Species  Month Day
# 2                 "A small shark"     1  17
# 3     Broadnose seven gill shark?     1  16
# 4                             NaN     1  13
# 5                             NaN     1  12
# 6                     Lemon shark     1   7
# ...                           ...   ...  ..
# 6237                          NaN     1  17
# 6249                          NaN     7  26
# 6256                          NaN     9  28
# 6274                          NaN     5  11
# 6320                          NaN     3  26
#
# [2953 rows x 15 columns]

# %%
# Step 10: Remove empty or indeterminant values in the "Time" column.

def clean_time(time):

    # Replace NaN with empty strings.

    if not isinstance(time, str):
        return ""
    
    # Must match the expected format.

    time = time.strip().strip("\"")

    re_match = re.match("^[0-9]+h[0-9]+$", time)

    # Format matched exactly.

    if re_match is not None:
        return time
    
    # Use averages for word-based times of day.

    if time == 'Midday':
        return "12h00"

    if time == 'Afternoon' or time == 'After noon' or time == 'Early afternoon':
        return "13h30"

    if time == 'Late afternoon':
        return "16h30"
    
    if time == 'Dusk' or time == 'Early evening' or time == 'Sunset':
        return "18h00"

    if time == 'Evening':
        return "19h00"

    if time == 'Night':
        return "20h00"

    if time == 'Dawn':
        return "03h00"

    if time == 'Early morning':
        return "06h00"

    if time == 'Morning':
        return "09h00"
    
    # If the time is solely numeric, reformat it.

    if time.isdigit():

        time_a = ''
        time_b = time[-3]
        time_c = time[-2]
        time_d = time[-1]

        if len(time) == 4:
            time_a = time[-4]
        else:
            time_a = '0'
        
        return time_a + time_b + 'h' + time_c + time_d

    # Did not match expected format, mark for deletion.

    return ""

shark_attacks["Time"] = shark_attacks["Time"].apply(clean_time)
shark_attacks = shark_attacks[~shark_attacks["Time"].str.match("^$")]

shark_attacks
# Out:
# C:\Users\skyli\AppData\Local\Temp\ipykernel_12400\2765263157.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_attacks["Time"] = shark_attacks["Time"].apply(clean_time)
#       index  Year        Type      Country                Area  \
# 2         2  2020  Unprovoked    AUSTRALIA     New South Wales
# 3         3  2020  Unprovoked  NEW ZEALAND           Southland
# 4         4  2020  Unprovoked          USA      North Carolina
# 5         5  2020  Unprovoked     THAILAND  Phang Nga Province
# 6         6  2020  Unprovoked    AUSTRALIA          Queensland
# ...     ...   ...         ...          ...                 ...
# 6118   6118  1863  Unprovoked    AUSTRALIA     New South Wales
# 6151   6151  1858  Unprovoked    AUSTRALIA            Victoria
# 6237   6237  1837  Unprovoked    AUSTRALIA     New South Wales
# 6274   6274  1817  Unprovoked    SRI LANKA    Western Province
# 6320   6320  1703  Unprovoked     BARBADOS     Southwest coast
#
#                                  Location          Activity Unnamed: 9 Age  \
# 2                           Windang Beach           Surfing          M  59
# 3                             Oreti Beach           Surfing          F  13
# 4                   Rodanthe, Dare County           Surfing          M  26
# 5                        Nang Thong Beach          Swimming          M  75
# 6                       North West Island          Swimming          F   7
# ...                                   ...               ...        ...  ..
# 6118  "Bellynahinch" on the Manning River           Bathing        NaN  17
# 6151                           Hobson Bay           Bathing        NaN  22
# 6237                        Macleay River  Washing his feet        NaN  12
# 6274                              Colombo          Swimming        NaN  22
# 6320                         Carlisle Bay          Swimming        NaN  19
#
#                                                  Injury Fatal (Y/N)   Time  \
# 2                     Laceration ot left ankle and foot           N  08h00
# 3                             Minor injury to lower leg           N  20h30
# 4                                   Lacerations to foot           N  14h33
# 5                                           Calf bitten           N  07h15
# 6                                    Lacerations to leg           N  17h30
# ...                                                 ...         ...    ...
# 6118                                              FATAL           Y  19h00
# 6151                                              FATAL           Y  15h00
# 6237            FATAL Injured by shark, died of tetanus           Y  19h00
# 6274                                              FATAL           Y  19h00
# 6320  Hand and foot severely bitten, surgically ampu...           N  20h00
#
#                          Species  Month Day
# 2                 "A small shark"     1  17
# 3     Broadnose seven gill shark?     1  16
# 4                             NaN     1  13
# 5                             NaN     1  12
# 6                     Lemon shark     1   7
# ...                           ...   ...  ..
# 6118                          NaN     1  10
# 6151                          NaN     3  14
# 6237                          NaN     1  17
# 6274                          NaN     5  11
# 6320                          NaN     3  26
#
# [2131 rows x 15 columns]

# %%
# Step 11: Rename "Species " column to "Species". Yes, there is an extra space.

shark_attacks = shark_attacks.rename(columns={"Species ": "Species"})

shark_attacks
# Out:
#       index  Year        Type      Country                Area  \
# 2         2  2020  Unprovoked    AUSTRALIA     New South Wales
# 3         3  2020  Unprovoked  NEW ZEALAND           Southland
# 4         4  2020  Unprovoked          USA      North Carolina
# 5         5  2020  Unprovoked     THAILAND  Phang Nga Province
# 6         6  2020  Unprovoked    AUSTRALIA          Queensland
# ...     ...   ...         ...          ...                 ...
# 6118   6118  1863  Unprovoked    AUSTRALIA     New South Wales
# 6151   6151  1858  Unprovoked    AUSTRALIA            Victoria
# 6237   6237  1837  Unprovoked    AUSTRALIA     New South Wales
# 6274   6274  1817  Unprovoked    SRI LANKA    Western Province
# 6320   6320  1703  Unprovoked     BARBADOS     Southwest coast
#
#                                  Location          Activity Unnamed: 9 Age  \
# 2                           Windang Beach           Surfing          M  59
# 3                             Oreti Beach           Surfing          F  13
# 4                   Rodanthe, Dare County           Surfing          M  26
# 5                        Nang Thong Beach          Swimming          M  75
# 6                       North West Island          Swimming          F   7
# ...                                   ...               ...        ...  ..
# 6118  "Bellynahinch" on the Manning River           Bathing        NaN  17
# 6151                           Hobson Bay           Bathing        NaN  22
# 6237                        Macleay River  Washing his feet        NaN  12
# 6274                              Colombo          Swimming        NaN  22
# 6320                         Carlisle Bay          Swimming        NaN  19
#
#                                                  Injury Fatal (Y/N)   Time  \
# 2                     Laceration ot left ankle and foot           N  08h00
# 3                             Minor injury to lower leg           N  20h30
# 4                                   Lacerations to foot           N  14h33
# 5                                           Calf bitten           N  07h15
# 6                                    Lacerations to leg           N  17h30
# ...                                                 ...         ...    ...
# 6118                                              FATAL           Y  19h00
# 6151                                              FATAL           Y  15h00
# 6237            FATAL Injured by shark, died of tetanus           Y  19h00
# 6274                                              FATAL           Y  19h00
# 6320  Hand and foot severely bitten, surgically ampu...           N  20h00
#
#                           Species Month Day
# 2                 "A small shark"     1  17
# 3     Broadnose seven gill shark?     1  16
# 4                             NaN     1  13
# 5                             NaN     1  12
# 6                     Lemon shark     1   7
# ...                           ...   ...  ..
# 6118                          NaN     1  10
# 6151                          NaN     3  14
# 6237                          NaN     1  17
# 6274                          NaN     5  11
# 6320                          NaN     3  26
#
# [2131 rows x 15 columns]

# %%
# Step 12: Replace empty values for "Species" with "Unknown".

def clean_empty_species(species):
    if not isinstance(species, str):
        return "Unknown"

    return species

shark_attacks["Species"] = shark_attacks["Species"].apply(clean_empty_species)

shark_attacks
# Out:
#       index  Year        Type      Country                Area  \
# 2         2  2020  Unprovoked    AUSTRALIA     New South Wales
# 3         3  2020  Unprovoked  NEW ZEALAND           Southland
# 4         4  2020  Unprovoked          USA      North Carolina
# 5         5  2020  Unprovoked     THAILAND  Phang Nga Province
# 6         6  2020  Unprovoked    AUSTRALIA          Queensland
# ...     ...   ...         ...          ...                 ...
# 6118   6118  1863  Unprovoked    AUSTRALIA     New South Wales
# 6151   6151  1858  Unprovoked    AUSTRALIA            Victoria
# 6237   6237  1837  Unprovoked    AUSTRALIA     New South Wales
# 6274   6274  1817  Unprovoked    SRI LANKA    Western Province
# 6320   6320  1703  Unprovoked     BARBADOS     Southwest coast
#
#                                  Location          Activity Unnamed: 9 Age  \
# 2                           Windang Beach           Surfing          M  59
# 3                             Oreti Beach           Surfing          F  13
# 4                   Rodanthe, Dare County           Surfing          M  26
# 5                        Nang Thong Beach          Swimming          M  75
# 6                       North West Island          Swimming          F   7
# ...                                   ...               ...        ...  ..
# 6118  "Bellynahinch" on the Manning River           Bathing        NaN  17
# 6151                           Hobson Bay           Bathing        NaN  22
# 6237                        Macleay River  Washing his feet        NaN  12
# 6274                              Colombo          Swimming        NaN  22
# 6320                         Carlisle Bay          Swimming        NaN  19
#
#                                                  Injury Fatal (Y/N)   Time  \
# 2                     Laceration ot left ankle and foot           N  08h00
# 3                             Minor injury to lower leg           N  20h30
# 4                                   Lacerations to foot           N  14h33
# 5                                           Calf bitten           N  07h15
# 6                                    Lacerations to leg           N  17h30
# ...                                                 ...         ...    ...
# 6118                                              FATAL           Y  19h00
# 6151                                              FATAL           Y  15h00
# 6237            FATAL Injured by shark, died of tetanus           Y  19h00
# 6274                                              FATAL           Y  19h00
# 6320  Hand and foot severely bitten, surgically ampu...           N  20h00
#
#                           Species Month Day
# 2                 "A small shark"     1  17
# 3     Broadnose seven gill shark?     1  16
# 4                         Unknown     1  13
# 5                         Unknown     1  12
# 6                     Lemon shark     1   7
# ...                           ...   ...  ..
# 6118                      Unknown     1  10
# 6151                      Unknown     3  14
# 6237                      Unknown     1  17
# 6274                      Unknown     5  11
# 6320                      Unknown     3  26
#
# [2131 rows x 15 columns]

# %%
# Step 13: Clean "Species" column to have only the name of the species.

# %%
# Step 14: Renamed "Unnamed: 9" to "Sex of Victim", where values of M, F, and U (unknown) are available.

shark_attacks = shark_attacks.rename(columns={"Unnamed: 9": "Sex of Victim"})

shark_attacks
# Out:
#       index  Year        Type      Country                Area  \
# 2         2  2020  Unprovoked    AUSTRALIA     New South Wales
# 3         3  2020  Unprovoked  NEW ZEALAND           Southland
# 4         4  2020  Unprovoked          USA      North Carolina
# 5         5  2020  Unprovoked     THAILAND  Phang Nga Province
# 6         6  2020  Unprovoked    AUSTRALIA          Queensland
# ...     ...   ...         ...          ...                 ...
# 6118   6118  1863  Unprovoked    AUSTRALIA     New South Wales
# 6151   6151  1858  Unprovoked    AUSTRALIA            Victoria
# 6237   6237  1837  Unprovoked    AUSTRALIA     New South Wales
# 6274   6274  1817  Unprovoked    SRI LANKA    Western Province
# 6320   6320  1703  Unprovoked     BARBADOS     Southwest coast
#
#                                  Location          Activity Sex of Victim Age  \
# 2                           Windang Beach           Surfing             M  59
# 3                             Oreti Beach           Surfing             F  13
# 4                   Rodanthe, Dare County           Surfing             M  26
# 5                        Nang Thong Beach          Swimming             M  75
# 6                       North West Island          Swimming             F   7
# ...                                   ...               ...           ...  ..
# 6118  "Bellynahinch" on the Manning River           Bathing           NaN  17
# 6151                           Hobson Bay           Bathing           NaN  22
# 6237                        Macleay River  Washing his feet           NaN  12
# 6274                              Colombo          Swimming           NaN  22
# 6320                         Carlisle Bay          Swimming           NaN  19
#
#                                                  Injury Fatal (Y/N)   Time  \
# 2                     Laceration ot left ankle and foot           N  08h00
# 3                             Minor injury to lower leg           N  20h30
# 4                                   Lacerations to foot           N  14h33
# 5                                           Calf bitten           N  07h15
# 6                                    Lacerations to leg           N  17h30
# ...                                                 ...         ...    ...
# 6118                                              FATAL           Y  19h00
# 6151                                              FATAL           Y  15h00
# 6237            FATAL Injured by shark, died of tetanus           Y  19h00
# 6274                                              FATAL           Y  19h00
# 6320  Hand and foot severely bitten, surgically ampu...           N  20h00
#
#                           Species Month Day
# 2                 "A small shark"     1  17
# 3     Broadnose seven gill shark?     1  16
# 4                         Unknown     1  13
# 5                         Unknown     1  12
# 6                     Lemon shark     1   7
# ...                           ...   ...  ..
# 6118                      Unknown     1  10
# 6151                      Unknown     3  14
# 6237                      Unknown     1  17
# 6274                      Unknown     5  11
# 6320                      Unknown     3  26
#
# [2131 rows x 15 columns]

# %%
# Step 15: Replace NaN values in Sex of Victim to U.

def clean_sex_of_victim(sex):
    if not isinstance(sex, str):
        return "U"
    
    if sex != "M" and sex != "F":
        return "U"

    return sex


shark_attacks["Sex of Victim"] = shark_attacks["Sex of Victim"].apply(clean_sex_of_victim)

shark_attacks
# Out:
#       index  Year        Type      Country                Area  \
# 2         2  2020  Unprovoked    AUSTRALIA     New South Wales
# 3         3  2020  Unprovoked  NEW ZEALAND           Southland
# 4         4  2020  Unprovoked          USA      North Carolina
# 5         5  2020  Unprovoked     THAILAND  Phang Nga Province
# 6         6  2020  Unprovoked    AUSTRALIA          Queensland
# ...     ...   ...         ...          ...                 ...
# 6118   6118  1863  Unprovoked    AUSTRALIA     New South Wales
# 6151   6151  1858  Unprovoked    AUSTRALIA            Victoria
# 6237   6237  1837  Unprovoked    AUSTRALIA     New South Wales
# 6274   6274  1817  Unprovoked    SRI LANKA    Western Province
# 6320   6320  1703  Unprovoked     BARBADOS     Southwest coast
#
#                                  Location          Activity Sex of Victim Age  \
# 2                           Windang Beach           Surfing             M  59
# 3                             Oreti Beach           Surfing             F  13
# 4                   Rodanthe, Dare County           Surfing             M  26
# 5                        Nang Thong Beach          Swimming             M  75
# 6                       North West Island          Swimming             F   7
# ...                                   ...               ...           ...  ..
# 6118  "Bellynahinch" on the Manning River           Bathing             U  17
# 6151                           Hobson Bay           Bathing             U  22
# 6237                        Macleay River  Washing his feet             U  12
# 6274                              Colombo          Swimming             U  22
# 6320                         Carlisle Bay          Swimming             U  19
#
#                                                  Injury Fatal (Y/N)   Time  \
# 2                     Laceration ot left ankle and foot           N  08h00
# 3                             Minor injury to lower leg           N  20h30
# 4                                   Lacerations to foot           N  14h33
# 5                                           Calf bitten           N  07h15
# 6                                    Lacerations to leg           N  17h30
# ...                                                 ...         ...    ...
# 6118                                              FATAL           Y  19h00
# 6151                                              FATAL           Y  15h00
# 6237            FATAL Injured by shark, died of tetanus           Y  19h00
# 6274                                              FATAL           Y  19h00
# 6320  Hand and foot severely bitten, surgically ampu...           N  20h00
#
#                           Species Month Day
# 2                 "A small shark"     1  17
# 3     Broadnose seven gill shark?     1  16
# 4                         Unknown     1  13
# 5                         Unknown     1  12
# 6                     Lemon shark     1   7
# ...                           ...   ...  ..
# 6118                      Unknown     1  10
# 6151                      Unknown     3  14
# 6237                      Unknown     1  17
# 6274                      Unknown     5  11
# 6320                      Unknown     3  26
#
# [2131 rows x 15 columns]

# %%
# Export new table as CSV.

#shark_attacks.to_csv("clean_GSAF5.xls.csv")
